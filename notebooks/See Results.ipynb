# %%
import h5py
import numpy as np
from spectral import *

# %%
# !ls ../checkpoints/cifar2hsi/web/images
# Out:
# epoch001_fake_A.hdf5  epoch004_rec_A.hdf5   epoch010_real_A.hdf5
# epoch001_fake_B.hdf5  epoch004_rec_B.hdf5   epoch010_real_B.hdf5
# epoch001_idt_A.hdf5   epoch006_fake_A.hdf5  epoch010_rec_A.hdf5
# epoch001_idt_B.hdf5   epoch006_fake_B.hdf5  epoch010_rec_B.hdf5
# epoch001_real_A.hdf5  epoch006_idt_A.hdf5   epoch012_fake_A.hdf5
# epoch001_real_B.hdf5  epoch006_idt_B.hdf5   epoch012_fake_B.hdf5
# epoch001_rec_A.hdf5   epoch006_real_A.hdf5  epoch012_idt_A.hdf5
# epoch001_rec_B.hdf5   epoch006_real_B.hdf5  epoch012_idt_B.hdf5
# epoch002_fake_A.hdf5  epoch006_rec_A.hdf5   epoch012_real_A.hdf5
# epoch002_fake_B.hdf5  epoch006_rec_B.hdf5   epoch012_real_B.hdf5
# epoch002_idt_A.hdf5   epoch008_fake_A.hdf5  epoch012_rec_A.hdf5
# epoch002_idt_B.hdf5   epoch008_fake_B.hdf5  epoch012_rec_B.hdf5
# epoch002_real_A.hdf5  epoch008_idt_A.hdf5   epoch014_fake_A.hdf5
# epoch002_real_B.hdf5  epoch008_idt_B.hdf5   epoch014_fake_B.hdf5
# epoch002_rec_A.hdf5   epoch008_real_A.hdf5  epoch014_idt_A.hdf5
# epoch002_rec_B.hdf5   epoch008_real_B.hdf5  epoch014_idt_B.hdf5
# epoch004_fake_A.hdf5  epoch008_rec_A.hdf5   epoch014_real_A.hdf5
# epoch004_fake_B.hdf5  epoch008_rec_B.hdf5   epoch014_real_B.hdf5
# epoch004_idt_A.hdf5   epoch010_fake_A.hdf5  epoch014_rec_A.hdf5
# epoch004_idt_B.hdf5   epoch010_fake_B.hdf5  epoch014_rec_B.hdf5
# epoch004_real_A.hdf5  epoch010_idt_A.hdf5
# epoch004_real_B.hdf5  epoch010_idt_B.hdf5

# %%
folder = 'cifar2hsi'
# folder = '4hsi_vanilla_version2'
epoch = '010'
filename = '../checkpoints/{0}/web/images/epoch{1}_real_B.hdf5'.format(folder, str(epoch))
with h5py.File(filename, 'r') as f:
    data = f['data']
    d1 = np.array(data)

filename = '../checkpoints/{0}/web/images/epoch{1}_fake_B.hdf5'.format(folder, str(epoch))
with h5py.File(filename, 'r') as f:
    data = f['data']
    d2 = np.array(data)
    
filename = '../checkpoints/{0}/web/images/epoch{1}_real_A.hdf5'.format(folder, str(epoch))
with h5py.File(filename, 'r') as f:
    data = f['data']
    d3 = np.array(data)

filename = '../checkpoints/{0}/web/images/epoch{1}_fake_A.hdf5'.format(folder, str(epoch))
with h5py.File(filename, 'r') as f:
    data = f['data']
    d4 = np.array(data)
    
filename = '../checkpoints/{0}/web/images/epoch{1}_rec_A.hdf5'.format(folder, str(epoch))
with h5py.File(filename, 'r') as f:
    data = f['data']
    d5 = np.array(data)

filename = '../checkpoints/{0}/web/images/epoch{1}_rec_B.hdf5'.format(folder, str(epoch))
with h5py.File(filename, 'r') as f:
    data = f['data']
    d6 = np.array(data)

# %%
view1 = imshow(d1)
print('Visualizing the GT hyperspectral image')
print(view1)
view3 = imshow(d3)
print('Visualizing the GT hazy image')
print(view3)
view2 = imshow(d2)
print('Visualizing the generated hyperspectral image. Should be more similar to GT hazy image')
print(view2)
# Out:
# Visualizing the GT hyperspectral image
# ImageView object:
#   Display bands       :  [0, 15.5, 30]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [112.102783203125, 1176.719482421875]
#     G: [565.5850830078125, 2340.94287109375]
#     B: [176.0762939453125, 1558.0330810546875]
#
# Visualizing the GT hazy image
# ImageView object:
#   Display bands       :  [0, 15.5, 30]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [240.941162109375, 3951.435302734375]
#     G: [208.815673828125, 3871.12158203125]
#     B: [176.690185546875, 3822.933349609375]
#
# Visualizing the generated hyperspectral image. Should be more similar to GT hazy image
# ImageView object:
#   Display bands       :  [0, 15.5, 30]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [25.5965576171875, 3665.2900390625]
#     G: [57.07470703125, 3743.4892578125]
#     B: [70.206298828125, 3616.42236328125]

# %%
view4 = imshow(d4)
print('Visualizing the generated RGB image. Should be similar to GT hyperspectral image')
print(view4)
view5 = imshow(d5)
print('Visualizing the Reconstructed RGB image.')
print(view5)
view6 = imshow(d6)
print('Visualizing the Reconstructed HSI image')
print(view6)
# Out:
# Visualizing the generated RGB image. Should be similar to GT hyperspectral image
# ImageView object:
#   Display bands       :  [0, 15.5, 30]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [288.497802734375, 1825.1478271484375]
#     G: [405.1318359375, 2192.64599609375]
#     B: [484.68310546875, 2792.05078125]
#
# Visualizing the Reconstructed RGB image.
# ImageView object:
#   Display bands       :  [0, 15.5, 30]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [120.156982421875, 3611.79833984375]
#     G: [273.844970703125, 3589.40185546875]
#     B: [302.43896484375, 3659.43017578125]
#
# Visualizing the Reconstructed HSI image
# ImageView object:
#   Display bands       :  [0, 15.5, 30]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [47.2183837890625, 2048.32763671875]
#     G: [147.3536376953125, 1684.765625]
#     B: [151.4212646484375, 1830.975341796875]
